# %%
# sys setup
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
# imports
import yaml
from src.data_generator import generate_sample_points
from src.io_utils import load_geodata
from src.preprocessing import preprocess
from src.spatial_analysis import buffer_points
from src.visualize import plot_leaflet

# %%
# load params
with open("../params/config.yml") as f:
    config = yaml.safe_load(f)
with open("../params/preprocessing.yml") as f:
    preproc_config = yaml.safe_load(f)

# %%
# generate data
generate_sample_points(config["input_file"])

# %%
# load and process
gdf = load_geodata(config["input_file"], config["crs"])
gdf = preprocess(gdf, preproc_config)
buffered = buffer_points(gdf, config["buffer_radius"])
gdf.head()
# Out:
#    id                  geometry
# 0   1  POINT (-73.5673 45.5017)
# 1   2    POINT (-73.567 45.502)
# 2   3  POINT (-73.5665 45.5023)

# %%
# leaflet plot
plot_leaflet(buffered)
# Out:
# /Users/canalytics/geospatial-params-demo/src/visualize.py:48: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   points["geometry"] = gdf.geometry.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
